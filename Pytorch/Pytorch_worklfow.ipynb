# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayank-Singh-X1/Pytorch-notes/blob/main/Pytorch/Pytorch_worklfow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch import nn
import matplotlib.pyplot as plt
# Out:
# '2.11.0+cpu'

# %%
w= 0.7
b= 0.3
X= torch.arange(0,1,0.02).unsqueeze(dim=1)
y= w*X + b
X[:10]
# Out:
# tensor([[0.0000],
#         [0.0200],
#         [0.0400],
#         [0.0600],
#         [0.0800],
#         [0.1000],
#         [0.1200],
#         [0.1400],
#         [0.1600],
#         [0.1800]])

# %% [markdown]
# Splitting data into train ans test

# %%
train_split = int(0.8 * len(X))
X_train, y_train = X[:train_split], y[:train_split]
X_test, y_test = X[train_split:] , y[train_split:]
len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (40, 40, 10, 10)
